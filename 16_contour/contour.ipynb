# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("../images/shapes.jpg")
image_rgb = cv2.cvtColor(image,cv2.COLOR_BGR2RGB)
image_grey = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(image_rgb)

# %%
plt.imshow(image_grey, cmap="grey")

# %%
print(image.shape)
# Out:
# (5000, 5000, 3)

# %%
image_resized = cv2.resize(image_grey, (700, 700))
grey_img = cv2.Canny(image_resized, 80, 150)

plt.figure(figsize=(10, 10))
plt.imshow(grey_img, cmap='gray')

plt.title("Edges on Resized Image")
plt.show()

# %%
print(grey_img.shape)
# Out:
# (700, 700)

# %%
contours, hierarchy = cv2.findContours(grey_img, cv2.RETR_LIST, cv2.CHAIN_APPROX_SIMPLE)

#MODE - hierarchy relationship between contours
# method - contours points are stored.

contour_image = grey_img.copy()
cv2.drawContours(contour_image, contours, -1, (0, 255, 0), 2)

plt.figure(figsize=(10,5))
plt.subplot(1,3,1)
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.title("Original image")

plt.subplot(1,3,2)
plt.imshow(grey, cmap='grey')
plt.title("maks")

plt.subplot(1,3,3)
plt.imshow(cv2.cvtColor(contour_image, cv2.COLOR_BGR2RGB))
plt.title("Contours image")

plt.show()

# %%
plt.imshow(grey)
